# %%
from sklearn.datasets import make_blobs, make_moons, make_circles, make_regression, make_checkerboard
from matplotlib import pyplot as plt
import pandas as pd
from pandas import DataFrame
import utils
# https://machinelearningmastery.com/generate-test-datasets-python-scikit-learn/
# generate 2d classification dataset
X, y = make_blobs(n_samples=5000, centers=5, n_features=2)
# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue', 2:'green', 3:'yellow', 4:'orange'}
fig, ax = plt.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
# generate 2d classification dataset
X2, y2 = make_moons(n_samples=5000, noise=0.15)
# scatter plot, dots colored by class value
df2 = DataFrame(dict(x=X2[:,0], y=X2[:,1], label=y2))
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df2.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
# generate 2d classification dataset
X3, y3 = make_circles(n_samples=5000, noise=0.075)
# scatter plot, dots colored by class value
df3 = DataFrame(dict(x=X3[:,0], y=X3[:,1], label=y3))
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df3.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
# generate regression dataset
X4, y4 = make_regression(n_samples=5000, n_features=1, noise=15)
# plot regression dataset
df4 = DataFrame(dict(x=X4[:,0], y=y4))
plt.scatter(X4,y4)
plt.show()

# %%
df.to_csv('datasets/blobs.csv', index=False)
df2.to_csv('datasets/moons.csv', index=False)
df3.to_csv('datasets/circles.csv', index=False)
df4.to_csv('datasets/regression.csv', index=False)

# %%
df5 = pd.read_csv('datasets/emotion.csv')
df5.head()
# Out:
#                                                 text  label
# 0  im feeling quite sad and sorry for myself but ...      0
# 1  i feel like i am still looking at a blank canv...      0
# 2                     i feel like a faithful servant      2
# 3                  i am just feeling cranky and blue      3
# 4  i can have for a treat or if i am feeling festive      1

# %%
utils.create_test_train_datasets()
